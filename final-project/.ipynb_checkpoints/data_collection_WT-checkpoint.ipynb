# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('./dataset/conserve_right/wttrump.csv')
df2 = pd.read_csv('./dataset/conserve_right/wttrump2.csv')
df3 = pd.read_csv('./dataset/conserve_right/wtchina.csv')
df4 = pd.read_csv('./dataset/conserve_right/wtchina2.csv')
# Out:
# 18194

# %%
links = []
titles = []
def get_title_and_link(df):
    dff = pd.DataFrame()
    for line in range(len(df)):
        link = df.loc[line]['link-href']
        if link[:37] == "https://www.washingtontimes.com/news/":   
            links.append(df.loc[line]['link-href'])
            titles.append(df.loc[line]['link'])

get_title_and_link(df1)
get_title_and_link(df2)
get_title_and_link(df3)
print(len(links),len(titles))
# Out:
# 6033 6033

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import time

# %%
# Empty lists for content, links and titles
news_contents = []
final_article = ""
count = 0
for link in links:
    # Request
    #print(link)
    r = requests.get(link)
    if r.status_code == requests.codes.ok:
        soup = BeautifulSoup(r.text, 'html.parser')
        stories = soup.find_all('p')
    # Unifying the paragraphs
    list_paragraphs = []
    for s in stories:
        list_paragraphs.append(s.getText())
    #print(list_paragraphs)
    final_article = " ".join(list_paragraphs)  
    # Removing special characters
    final_article = re.sub("\\xa0","", final_article)
    final_article = re.sub(r"[^a-zA-Z0-9]+", ' ',final_article.lower())
    
    news_contents.append(final_article)
# Out:
# 3124
# 8349
# 1939
# 4852
# 4419
# 3440
# 28523
# 9288
# 4153
# 1340
# 4160
# 9426
# 3063
# 1476
# 1485
# 2950
# 6962
# 2882
# 1130
# 7307
# 5154
# 5455
# 2424
# 5251
# 3543
# 6879
# 3673
# 9727
# 2314
# 5840
# 2393
# 3867
# 6811
# 3075
# 2077
# 6560
# 3006
# 6073
# 5716
# 9027
# 2351
# 2461
# 6561
# 2212
# 5141
# 1693
# 7354
# 5972
# 3597
# 3835
# 2353
# 5641
# 2772
# 4178
# 3510
# 5229
# 5509
# 5952
# 2861
# 6726
# 2459
# 6518
# 3300
# 4206
# 5096
# 3633
# 4895
# 3351
# 13513
# 2639
# 10735
# 4979
# 6481
# 1437
# 8341
# 4594
# 7238
# 6496
# 8337
# 3300
# 3305
# 4108
# 2849
# 2496
# 13662
# 1560
# 6937
# 6732
# 1430
# 2764
# 2072
# 6657
# 2839
# 1516
# 7138
# 2935
# 8322
# 6371
# 8773
# 2445
# 2360
# 6206
# 4036
# 5659
# 3951
# 4249
# 3989
# 2219
# 1618
# 7481
# 3270
# 4291
# 2162
# 3904
# 8073
# 8281
# 3854
# 2943
# 6311
# 2759
# 7362
# 2947
# 4852
# 4201
# 3014
# 6126
# 6044
# 5118
# 1936
# 2731
# 1442
# 5088
# 1694
# 5973
# 2717
# 2879
# 1623
# 5971
# 4390
# 7580
# 3846
# 14183
# ...

# %%
# df_features
lable = ['right' for i in range(len(titles))]
df_features = pd.DataFrame(
    {'Article Title': titles,
     'Article Content': news_contents,
     'Category': lable
    })

# %%
df_features.head(20)

# %%
df_features.to_csv('./dataset/conserve_right/processWTnews.csv', index = False, header=True)
